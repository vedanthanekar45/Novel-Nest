# %%
#Assignment on Association Rule Learning
#Download Market Basket Optimization dataset from below link. Data Set:
#https://www.kaggle.com/hemanthkumar05/market-basket-optimization
#This dataset comprises the list of transactions of a retail company over the
#period of one week. It contains a total of 7501 transaction records where
#each record consists of the list of items sold in one transaction. Using this
#record of transactions and items in each transaction, find the association
#rules between items. There is no header in the dataset and the first row
#contains the first transaction, so mentioned header = None here while
#loading dataset. Follow following steps:
#Data Preprocessing
#Generate the list of transactions from the dataset
#Train Apriori algorithm on the dataset
#Visualize the list of rules
#Generated rules depend on the values of hyper parameters. By increasing
#the minimum confidence value and find the rules accordingly

# %%
import pandas as pd

# %%
data = pd.read_csv('Market_Basket_Optimisation.csv' , header = None)
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
transaction = []
for i in range (0 , len(data)):
    transaction.append([str(data.values[i,j])
    for j in range (0 , 20)
        if str(data.values[i,j]) != 'nan'])

# %%
# Step 4: Convert transactions into one-hot encoded format for Apriori
from mlxtend.preprocessing import TransactionEncoder

# %%
t = TransactionEncoder()
t_ary = t.fit(transaction).transform(transaction)
df = pd.DataFrame(t_ary , columns = t.columns_)
df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules
frequent_itemsets = apriori(df , min_support = 0.003 , use_colnames = 0.2)
# Step 6: Generate Association Rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2, support_only=False)  # Adjust confidence threshold
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6aa2f248394a> in <cell line: 4>()
#       2 frequent_itemsets = apriori(df , min_support = 0.003 , use_colnames = 0.2)
#       3 # Step 6: Generate Association Rules
# ----> 4 rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2, support_only=False)  # Adjust confidence threshold
#       5
#
# TypeError: association_rules() missing 1 required positional argument: 'num_itemsets'

# %%
# Step 7: Visualize the rules (support vs confidence)
import matplotlib.pyplot as plt
plt.scatter(rules['support'], rules['confidence'], alpha=0.5)
plt.title('Support vs Confidence')
plt.xlabel('Support')
plt.ylabel('Confidence')
plt.show()

# %%
rules_high_confidence = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
print(rules_high_confidence[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
